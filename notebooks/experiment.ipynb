# %%
import pandas as pd

# %%
attr = pd.read_csv("../../list_attr_celeba.csv", index_col="image_id")

# %%
attr.head()
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# image_id
# 000001.jpg                -1                1           1               -1
# 000002.jpg                -1               -1          -1                1
# 000003.jpg                -1               -1          -1               -1
# 000004.jpg                -1               -1           1               -1
# 000005.jpg                -1                1           1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# image_id                                                             ...
# 000001.jpg    -1     -1        -1        -1          -1          -1  ...
# 000002.jpg    -1     -1        -1         1          -1          -1  ...
# 000003.jpg    -1     -1         1        -1          -1          -1  ...
# 000004.jpg    -1     -1        -1        -1          -1          -1  ...
# ...

# %%
attr.loc[(attr["Smiling"]==1) & (attr.sum(axis=1)==-36)]
# Out:
#             5_o_Clock_Shadow  Arched_Eyebrows  Attractive  Bags_Under_Eyes  \
# image_id
# 085255.jpg                -1               -1          -1               -1
#
#             Bald  Bangs  Big_Lips  Big_Nose  Black_Hair  Blond_Hair  ...  \
# image_id                                                             ...
# 085255.jpg    -1     -1        -1        -1          -1          -1  ...
#
#             Sideburns  Smiling  Straight_Hair  Wavy_Hair  Wearing_Earrings  \
# image_id
# 085255.jpg         -1        1             -1         -1                -1
#
#             Wearing_Hat  Wearing_Lipstick  Wearing_Necklace  Wearing_Necktie  \
# image_id
# 085255.jpg           -1                -1                -1               -1
#
#             Young
# image_id
# 085255.jpg     -1
#
# [1 rows x 40 columns]

# %%
list(attr.columns)
# Out:
# ['5_o_Clock_Shadow',
#  'Arched_Eyebrows',
#  'Attractive',
#  'Bags_Under_Eyes',
#  'Bald',
#  'Bangs',
#  'Big_Lips',
#  'Big_Nose',
#  'Black_Hair',
#  'Blond_Hair',
#  'Blurry',
#  'Brown_Hair',
#  'Bushy_Eyebrows',
#  'Chubby',
#  'Double_Chin',
#  'Eyeglasses',
#  'Goatee',
#  'Gray_Hair',
#  'Heavy_Makeup',
#  'High_Cheekbones',
#  'Male',
#  'Mouth_Slightly_Open',
#  'Mustache',
#  'Narrow_Eyes',
#  'No_Beard',
#  'Oval_Face',
#  'Pale_Skin',
#  'Pointy_Nose',
#  'Receding_Hairline',
#  'Rosy_Cheeks',
#  'Sideburns',
#  'Smiling',
#  'Straight_Hair',
#  'Wavy_Hair',
#  'Wearing_Earrings',
#  'Wearing_Hat',
#  'Wearing_Lipstick',
#  'Wearing_Necklace',
#  'Wearing_Necktie',
#  'Young']

# %% [markdown]
# ## Download celeba

# %%
from torchvision import datasets

# %%
celeba = datasets.CelebA(root="../data/", split="all", target_type="attr", download=True)
# Out:
# 1443490838it [03:10, 7592077.98it/s]
# 26721026it [00:03, 8040615.00it/s]
# 3424458it [00:00, 5830257.33it/s]
# 6082035it [00:00, 8983208.18it/s]
# 12156055it [00:01, 7870351.34it/s]
# 2836386it [00:00, 5397670.34it/s]
